# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(-50, 50)
delta = np.random.uniform(-15, 15, 100)
y = 0.5 * x + 2 + delta

# %%
df = pd.DataFrame({'x': x, 'y': y})
df.to_csv("pca-data.csv", index=False)

# %%
plt.scatter(x, y)
